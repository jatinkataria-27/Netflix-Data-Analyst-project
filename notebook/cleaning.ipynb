# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\jatin\Downloads\netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB

# %%
df.drop(columns = "date_added",inplace = True)

# %%
df.drop(columns = "cast",inplace = True)

# %%
df.drop(columns = "description",inplace = True)

# %%
df.head()
# Out:
#   show_id     type                  title         director        country  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s2  TV Show          Blood & Water              NaN   South Africa
# 2      s3  TV Show              Ganglands  Julien Leclercq            NaN
# 3      s4  TV Show  Jailbirds New Orleans              NaN            NaN
# 4      s5  TV Show           Kota Factory              NaN          India
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# ...

# %%
new_column_names = []

for i  in df.columns:
  new_column_names.append(i.capitalize())

# %%
new_column_names
# Out:
# ['Show_id',
#  'Type',
#  'Title',
#  'Director',
#  'Country',
#  'Release_year',
#  'Rating',
#  'Duration',
#  'Listed_in']

# %%
df.columns=new_column_names

# %%
df.head()
# Out:
#   Show_id     Type                  Title         Director        Country  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s2  TV Show          Blood & Water              NaN   South Africa
# 2      s3  TV Show              Ganglands  Julien Leclercq            NaN
# 3      s4  TV Show  Jailbirds New Orleans              NaN            NaN
# 4      s5  TV Show           Kota Factory              NaN          India
#
#    Release_year Rating   Duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
#
#                                            Listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Show_id            0
# Type               0
# Title              0
# Director        2634
# Country          831
# Release_year       0
# Rating             4
# Duration           3
# Listed_in          0
# dtype: int64

# %%
df.dtypes
# Out:
# Show_id           str
# Type              str
# Title             str
# Director          str
# Country           str
# Release_year    int64
# Rating            str
# Duration          str
# Listed_in         str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_id       8807 non-null   str
#  1   Type          8807 non-null   str
#  2   Title         8807 non-null   str
#  3   Director      6173 non-null   str
#  4   Country       7976 non-null   str
#  5   Release_year  8807 non-null   int64
#  6   Rating        8803 non-null   str
#  7   Duration      8804 non-null   str
#  8   Listed_in     8807 non-null   str
# dtypes: int64(1), str(8)
# memory usage: 619.4 KB

# %%
df.describe()
# Out:
#        Release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.nunique()
# Out:
# Show_id         8807
# Type               2
# Title           8807
# Director        4528
# Country          748
# Release_year      74
# Rating            17
# Duration         220
# Listed_in        514
# dtype: int64

# %%
df.isna().sum()
# Out:
# Show_id            0
# Type               0
# Title              0
# Director        2634
# Country          831
# Release_year       0
# Rating             4
# Duration           3
# Listed_in          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Show_id            0
# Type               0
# Title              0
# Director        2634
# Country          831
# Release_year       0
# Rating             4
# Duration           3
# Listed_in          0
# dtype: int64

# %%
df["Show_id"]=df["Show_id"].apply(lambda x: x.split("s")[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df["Show_id"]=df["Show_id"].apply(lambda x: x.split("s")[1])
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#      Show_id     Type                  Title         Director        Country  \
# 0          1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1          2  TV Show          Blood & Water              NaN   South Africa
# 2          3  TV Show              Ganglands  Julien Leclercq            NaN
# 3          4  TV Show  Jailbirds New Orleans              NaN            NaN
# 4          5  TV Show           Kota Factory              NaN          India
# ...      ...      ...                    ...              ...            ...
# 8802    8803    Movie                 Zodiac    David Fincher  United States
# 8803    8804  TV Show            Zombie Dumb              NaN            NaN
# 8804    8805    Movie             Zombieland  Ruben Fleischer  United States
# 8805    8806    Movie                   Zoom     Peter Hewitt  United States
# 8806    8807    Movie                 Zubaan      Mozez Singh          India
#
#       Release_year Rating   Duration  \
# ...

# %%
df.to_csv("Cleaned_Data_CSV.csv",index = False)

# %%
df.to_excel("Cleaned_Data_Excel.xlsx",index = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df.isnull().sum())
#
# NameError: name 'df' is not defined
